# %%
import requests
from urllib.parse import unquote

saved_file = 'asterix_char1.json'
use_category = True

#base_url = 'https://lotr.fandom.com'
#base_url = 'https://harrypotter.fandom.com'
#base_url = 'https://asterix.fandom.com'
#base_url = 'https://thehungergames.fandom.com'
base_url = 'https://asterix.fandom.com/fr'
#base_url = 'https://narnia.fandom.com'


result = requests.get(base_url+'/sitemap-newsitemapxml-index.xml')

c = result.content
print(c)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<sitemapindex xmlns="http://www.sitemaps.org/schemas/sitemap/0.9">\n<sitemap><loc>https://asterix.fandom.com/fr/sitemap-newsitemapxml-NS_0-id-7-4151.xml</loc></sitemap>\n<sitemap><loc>https://asterix.fandom.com/fr/sitemap-newsitemapxml-NS_14-id-64-3852.xml</loc></sitemap>\n<sitemap><loc>https://services.fandom.com/discussions-sitemap/sitemap/46931</loc></sitemap>\n</sitemapindex>\n<!-- Generation time: 5ms -->\n<!-- Generation date: 2021-10-14T05:06:06Z -->\n'

# %%
from bs4 import BeautifulSoup 
import lxml
import xml.etree.ElementTree as ET
root = ET.fromstring(c)
for link in root.iter('{http://www.sitemaps.org/schemas/sitemap/0.9}loc'):
    print(link.text)
# Out:
# https://asterix.fandom.com/fr/sitemap-newsitemapxml-NS_0-id-7-4151.xml
# https://asterix.fandom.com/fr/sitemap-newsitemapxml-NS_14-id-64-3852.xml
# https://services.fandom.com/discussions-sitemap/sitemap/46931

# %%
elements = dict()
for page in root.iter('{http://www.sitemaps.org/schemas/sitemap/0.9}loc'):
    result = requests.get(page.text)
    c = result.content
    new_root = ET.fromstring(c)
    for element in new_root.iter('{http://www.sitemaps.org/schemas/sitemap/0.9}loc'):
        elements[element.text.split('/')[-1]] = element.text
print('Found {} elements'.format(len(elements)))
# Out:
# Found 519 elements

# %%
#elements.items()

# %%
characters_dict = {}
if use_category:
    counter=0
    count = 0
    for k,v in elements.items():
        count+=1
        result = requests.get(v)
        c = result.content
        soup = BeautifulSoup(c, "html.parser")  # parse HTML page 
        links = soup.find_all("div", class_='page-header__categories')
        #links2 = soup.find_all("a", class_='page-header__categories')https://lotr.fandom.com/wiki/Category:Characters_in_The_History_of_Middle-earth
        try:
            if '/fr/wiki/Cat%C3%A9gorie:Personnages' in str(links[0]):
                print("aaa")
                characters_dict[k] = v
                counter+=1
                if counter in range(0,10000,300):
                    print('%s added to the dict, dict len: %s' %(k,str(len(characters_dict))))
        except:
            continue
else:
    characters_dict = elements
# Out:
# []
# [<div class="page-header__categories">
# <span class="page-header__categories-in">dans :</span>
# <a data-tracking-label="categories-top-more-0" href="/fr/wiki/Cat%C3%A9gorie:Auteurs" title="Catégorie:Auteurs">Auteurs</a>, <a data-tracking-label="categories-top-more-1" href="/fr/wiki/Cat%C3%A9gorie:Personnalit%C3%A9s" title="Catégorie:Personnalités">Personnalités</a>, <a class="newcategory" data-tracking-label="categories-top-more-2" href="/fr/wiki/Cat%C3%A9gorie:Pages_utilisant_des_liens_magiques_ISBN" title="Catégorie:Pages utilisant des liens magiques ISBN">Pages utilisant des liens magiques ISBN</a> </div>]
# [<div class="page-header__categories">
# <span class="page-header__categories-in">dans :</span>
# <a data-tracking-label="categories-top-more-0" href="/fr/wiki/Cat%C3%A9gorie:Auteurs" title="Catégorie:Auteurs">Auteurs</a>, <a data-tracking-label="categories-top-more-1" href="/fr/wiki/Cat%C3%A9gorie:Personnalit%C3%A9s" title="Catégorie:Personnalités">Personnalités</a>, <a data-tracking-label="categories-top-more-2" href="/fr/wiki/Cat%C3%A9gorie:Navigation" title="Catégorie:Navigation">Navigation</a> </div>]
# [<div class="page-header__categories">
# <span class="page-header__categories-in">dans :</span>
# <a data-tracking-label="categories-top-more-0" href="/fr/wiki/Cat%C3%A9gorie:Personnages" title="Catégorie:Personnages">Personnages</a>, <a data-tracking-label="categories-top-more-1" href="/fr/wiki/Cat%C3%A9gorie:Personnages_masculins" title="Catégorie:Personnages masculins">Personnages masculins</a>, <a data-tracking-label="categories-top-more-2" href="/fr/wiki/Cat%C3%A9gorie:Gaulois" title="Catégorie:Gaulois">Gaulois</a>, 			<div class="wds-dropdown page-header__categories-dropdown">
# <span>et</span>
# <a class="wds-dropdown__toggle" data-tracking="categories-more">74 autres</a>
# <div class="wds-dropdown__content page-header__categories-dropdown-content wds-is-left-aligned">
# <ul class="wds-list wds-is-linked">
# <li>
# <a data-tracking-label="categories-top-more-3" href="/fr/wiki/Cat%C3%A9gorie:Habitants_du_Village_gaulois" title="Catégorie:Habitants du Village gaulois">Habitants du Village gaulois</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-4" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_bandes_dessin%C3%A9es" title="Catégorie:Personnages de bandes dessinées">Personnages de bandes dessinées</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-5" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_films_d%27animations" title="Catégorie:Personnages de films d'animations">Personnages de films d'animations</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-6" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_films_en_prises_de_vues_r%C3%A9elles" title="Catégorie:Personnages de films en prises de vues réelles">Personnages de films en prises de vues réelles</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-7" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_jeux_vid%C3%A9o" title="Catégorie:Personnages de jeux vidéo">Personnages de jeux vidéo</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-8" href="/fr/wiki/Cat%C3%A9gorie:Personnages_principaux" title="Catégorie:Personnages principaux">Personnages principaux</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-9" href="/fr/wiki/Cat%C3%A9gorie:Guerriers" title="Catégorie:Guerriers">Guerriers</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-10" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_Maxi-D%C3%A9lirium" title="Catégorie:Astérix Maxi-Délirium">Astérix Maxi-Délirium</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-11" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_le_Gaulois_(film)" title="Catégorie:Personnages d'Astérix le Gaulois (film)">Personnages d'Astérix le Gaulois (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-12" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_le_Gaulois_(film)" title="Catégorie:Astérix le Gaulois (film)">Astérix le Gaulois (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-13" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_Cl%C3%A9opatre_(film)" title="Catégorie:Personnages d'Astérix et Cléopatre (film)">Personnages d'Astérix et Cléopatre (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-14" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_et_Cl%C3%A9opatre_(film)" title="Catégorie:Astérix et Cléopatre (film)">Astérix et Cléopatre (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-15" href="/fr/wiki/Cat%C3%A9gorie:Personnages_des_Douze_Travaux_d%27Ast%C3%A9rix_(film)" title="Catégorie:Personnages des Douze Travaux d'Astérix (film)">Personnages des Douze Travaux d'Astérix (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-16" href="/fr/wiki/Cat%C3%A9gorie:Les_Douze_Travaux_d%27Ast%C3%A9rix_(film)" title="Catégorie:Les Douze Travaux d'Astérix (film)">Les Douze Travaux d'Astérix (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-17" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_la_Surprise_de_C%C3%A9sar_(film)" title="Catégorie:Personnages d'Astérix et la Surprise de César (film)">Personnages d'Astérix et la Surprise de César (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-18" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_et_la_Surprise_de_C%C3%A9sar_(film)" title="Catégorie:Astérix et la Surprise de César (film)">Astérix et la Surprise de César (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-19" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_les_Bretons_(film)" title="Catégorie:Personnages d'Astérix chez les Bretons (film)">Personnages d'Astérix chez les Bretons (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-20" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_les_Bretons(film)" title="Catégorie:Personnages d'Astérix chez les Bretons(film)">Personnages d'Astérix chez les Bretons(film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-21" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_le_Coup_du_Menhir_(film)" title="Catégorie:Personnages d'Astérix et le Coup du Menhir (film)">Personnages d'Astérix et le Coup du Menhir (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-22" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_et_le_Coup_du_Menhir_(film)" title="Catégorie:Astérix et le Coup du Menhir (film)">Astérix et le Coup du Menhir (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-23" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_les_Indiens_(film)" title="Catégorie:Personnages d'Astérix et les Indiens (film)">Personnages d'Astérix et les Indiens (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-24" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_et_les_Indiens_(film)" title="Catégorie:Astérix et les Indiens (film)">Astérix et les Indiens (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-25" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_les_Vikings_(film)" title="Catégorie:Personnages d'Astérix et les Vikings (film)">Personnages d'Astérix et les Vikings (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-26" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_et_les_Vikings_(film)" title="Catégorie:Astérix et les Vikings (film)">Astérix et les Vikings (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-27" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_:_Le_Domaine_des_Dieux_(film)" title="Catégorie:Personnages d'Astérix : Le Domaine des Dieux (film)">Personnages d'Astérix : Le Domaine des Dieux (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-28" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_:_Le_Domaine_des_Dieux_(film)" title="Catégorie:Astérix : Le Domaine des Dieux (film)">Astérix : Le Domaine des Dieux (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-29" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_:_Le_Secret_de_la_Potion_Magique_(film)" title="Catégorie:Personnages d'Astérix : Le Secret de la Potion Magique (film)">Personnages d'Astérix : Le Secret de la Potion Magique (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-30" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_:_Le_Secret_de_la_Potion_Magique_(film)" title="Catégorie:Astérix : Le Secret de la Potion Magique (film)">Astérix : Le Secret de la Potion Magique (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-31" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_Ob%C3%A9lix_contre_C%C3%A9sar_(film)" title="Catégorie:Personnages d'Astérix et Obélix contre César (film)">Personnages d'Astérix et Obélix contre César (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-32" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_aux_Jeux_Olympiques_(film)" title="Catégorie:Personnages d'Astérix aux Jeux Olympiques (film)">Personnages d'Astérix aux Jeux Olympiques (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-33" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_et_Ob%C3%A9lix_contre_C%C3%A9sar_(film)" title="Catégorie:Astérix et Obélix contre César (film)">Astérix et Obélix contre César (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-34" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_aux_Jeux_Olympiques_(film)" title="Catégorie:Astérix aux Jeux Olympiques (film)">Astérix aux Jeux Olympiques (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-35" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_et_Ob%C3%A9lix_:_Au_service_de_Sa_Majest%C3%A9" title="Catégorie:Astérix et Obélix : Au service de Sa Majesté">Astérix et Obélix : Au service de Sa Majesté</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-36" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_Ob%C3%A9lix_:_Au_service_de_Sa_Majest%C3%A9" title="Catégorie:Personnages d'Astérix et Obélix : Au service de Sa Majesté">Personnages d'Astérix et Obélix : Au service de Sa Majesté</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-37" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_le_Gaulois" title="Catégorie:Personnages d'Astérix le Gaulois">Personnages d'Astérix le Gaulois</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-38" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_les_Goths" title="Catégorie:Personnages d'Astérix et les Goths">Personnages d'Astérix et les Goths</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-39" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_la_Serpe_d%27Or" title="Catégorie:Personnages de la Serpe d'Or">Personnages de la Serpe d'Or</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-40" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_Gladiateur" title="Catégorie:Personnages d'Astérix Gladiateur">Personnages d'Astérix Gladiateur</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-41" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_la_Tour_de_Gaule_d%27Ast%C3%A9rix" title="Catégorie:Personnages de la Tour de Gaule d'Astérix">Personnages de la Tour de Gaule d'Astérix</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-42" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_Cl%C3%A9opatre" title="Catégorie:Personnages d'Astérix et Cléopatre">Personnages d'Astérix et Cléopatre</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-43" href="/fr/wiki/Cat%C3%A9gorie:Personnage_du_Combat_des_Chefs" title="Catégorie:Personnage du Combat des Chefs">Personnage du Combat des Chefs</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-44" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_les_Bretons" title="Catégorie:Personnages d'Astérix chez les Bretons">Personnages d'Astérix chez les Bretons</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-45" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_les_Normands" title="Catégorie:Personnages d'Astérix et les Normands">Personnages d'Astérix et les Normands</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-46" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_l%C3%A9gionnaire" title="Catégorie:Personnages d'Astérix légionnaire">Personnages d'Astérix légionnaire</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-47" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Bouclier_Arverne" title="Catégorie:Personnages du Bouclier Arverne">Personnages du Bouclier Arverne</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-48" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_aux_Jeux_Olympiques" title="Catégorie:Personnages d'Astérix aux Jeux Olympiques">Personnages d'Astérix aux Jeux Olympiques</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-49" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_le_Chaudron" title="Catégorie:Personnages d'Astérix et le Chaudron">Personnages d'Astérix et le Chaudron</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-50" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_en_Hispanie" title="Catégorie:Personnages d'Astérix en Hispanie">Personnages d'Astérix en Hispanie</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-51" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_La_Zizanie" title="Catégorie:Personnages de La Zizanie">Personnages de La Zizanie</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-52" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_les_Helv%C3%A8tes" title="Catégorie:Personnages d'Astérix chez les Helvètes">Personnages d'Astérix chez les Helvètes</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-53" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Domaine_des_Dieux" title="Catégorie:Personnages du Domaine des Dieux">Personnages du Domaine des Dieux</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-54" href="/fr/wiki/Cat%C3%A9gorie:Personnages_des_Lauriers_de_C%C3%A9sar" title="Catégorie:Personnages des Lauriers de César">Personnages des Lauriers de César</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-55" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Devin" title="Catégorie:Personnages du Devin">Personnages du Devin</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-56" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_en_Corse" title="Catégorie:Personnages d'Astérix en Corse">Personnages d'Astérix en Corse</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-57" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Cadeau_de_C%C3%A9sar" title="Catégorie:Personnages du Cadeau de César">Personnages du Cadeau de César</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-58" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_La_Grande_Travers%C3%A9e" title="Catégorie:Personnages de La Grande Traversée">Personnages de La Grande Traversée</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-59" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ob%C3%A9lix_et_Compagnie" title="Catégorie:Personnages d'Obélix et Compagnie">Personnages d'Obélix et Compagnie</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-60" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_les_Belges" title="Catégorie:Personnages d'Astérix chez les Belges">Personnages d'Astérix chez les Belges</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-61" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Grand_Foss%C3%A9" title="Catégorie:Personnages du Grand Fossé">Personnages du Grand Fossé</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-62" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_l%27Odyss%C3%A9e_d%27Ast%C3%A9rix" title="Catégorie:Personnages de l'Odyssée d'Astérix">Personnages de l'Odyssée d'Astérix</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-63" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Fils_d%27Ast%C3%A9rix" title="Catégorie:Personnages du Fils d'Astérix">Personnages du Fils d'Astérix</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-64" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_Rahazade" title="Catégorie:Personnages d'Astérix chez Rahazade">Personnages d'Astérix chez Rahazade</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-65" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_Latraviata" title="Catégorie:Personnages d'Astérix et Latraviata">Personnages d'Astérix et Latraviata</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-66" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_La_Rose_et_le_Glaive" title="Catégorie:Personnages de La Rose et le Glaive">Personnages de La Rose et le Glaive</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-67" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_la_Gal%C3%A8re_d%27Ob%C3%A9lix" title="Catégorie:Personnages de la Galère d'Obélix">Personnages de la Galère d'Obélix</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-68" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_la_Rentr%C3%A9e_Gauloise" title="Catégorie:Personnages d'Astérix et la Rentrée Gauloise">Personnages d'Astérix et la Rentrée Gauloise</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-69" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Ciel_lui_Tombe_sur_la_T%C3%AAte" title="Catégorie:Personnages du Ciel lui Tombe sur la Tête">Personnages du Ciel lui Tombe sur la Tête</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-70" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_l%E2%80%99Anniversaire_d%E2%80%99Ast%C3%A9rix_et_Ob%C3%A9lix_%E2%80%93_Le_Livre_d%E2%80%99or" title="Catégorie:Personnages de l’Anniversaire d’Astérix et Obélix – Le Livre d’or">Personnages de l’Anniversaire d’Astérix et Obélix – Le Livre d’or</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-71" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_les_Pictes" title="Catégorie:Personnages d'Astérix chez les Pictes">Personnages d'Astérix chez les Pictes</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-72" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Papyrus_de_C%C3%A9sar" title="Catégorie:Personnages du Papyrus de César">Personnages du Papyrus de César</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-73" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_la_Transitalique" title="Catégorie:Personnages d'Astérix et la Transitalique">Personnages d'Astérix et la Transitalique</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-74" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_La_Fille_de_Vercing%C3%A9torix" title="Catégorie:Personnages de La Fille de Vercingétorix">Personnages de La Fille de Vercingétorix</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-75" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Menhir_d%27or" title="Catégorie:Personnages du Menhir d'or">Personnages du Menhir d'or</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-76" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Combat_des_Chefs" title="Catégorie:Personnages du Combat des Chefs">Personnages du Combat des Chefs</a> </li>
# </ul>
# </div>
# </div>
# </div>]
# aaa
# [<div class="page-header__categories">
# <span class="page-header__categories-in">dans :</span>
# <a data-tracking-label="categories-top-more-0" href="/fr/wiki/Cat%C3%A9gorie:Personnages" title="Catégorie:Personnages">Personnages</a>, <a data-tracking-label="categories-top-more-1" href="/fr/wiki/Cat%C3%A9gorie:Personnages_masculins" title="Catégorie:Personnages masculins">Personnages masculins</a>, <a data-tracking-label="categories-top-more-2" href="/fr/wiki/Cat%C3%A9gorie:Gaulois" title="Catégorie:Gaulois">Gaulois</a>, 			<div class="wds-dropdown page-header__categories-dropdown">
# <span>et</span>
# <a class="wds-dropdown__toggle" data-tracking="categories-more">57 autres</a>
# <div class="wds-dropdown__content page-header__categories-dropdown-content wds-is-left-aligned">
# <ul class="wds-list wds-is-linked">
# <li>
# <a data-tracking-label="categories-top-more-3" href="/fr/wiki/Cat%C3%A9gorie:Marchands" title="Catégorie:Marchands">Marchands</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-4" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_bandes_dessin%C3%A9es" title="Catégorie:Personnages de bandes dessinées">Personnages de bandes dessinées</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-5" href="/fr/wiki/Cat%C3%A9gorie:Personnages_principaux" title="Catégorie:Personnages principaux">Personnages principaux</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-6" href="/fr/wiki/Cat%C3%A9gorie:Habitants_du_Village_gaulois" title="Catégorie:Habitants du Village gaulois">Habitants du Village gaulois</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-7" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_Maxi-D%C3%A9lirium" title="Catégorie:Astérix Maxi-Délirium">Astérix Maxi-Délirium</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-8" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_films_d%27animations" title="Catégorie:Personnages de films d'animations">Personnages de films d'animations</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-9" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_en_Corse" title="Catégorie:Personnages d'Astérix en Corse">Personnages d'Astérix en Corse</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-10" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Papyrus_de_C%C3%A9sar" title="Catégorie:Personnages du Papyrus de César">Personnages du Papyrus de César</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-11" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_Latraviata" title="Catégorie:Personnages d'Astérix et Latraviata">Personnages d'Astérix et Latraviata</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-12" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_la_Rentr%C3%A9e_Gauloise" title="Catégorie:Personnages d'Astérix et la Rentrée Gauloise">Personnages d'Astérix et la Rentrée Gauloise</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-13" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_les_Bretons" title="Catégorie:Personnages d'Astérix chez les Bretons">Personnages d'Astérix chez les Bretons</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-14" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_en_Hispanie" title="Catégorie:Personnages d'Astérix en Hispanie">Personnages d'Astérix en Hispanie</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-15" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_Rahazade" title="Catégorie:Personnages d'Astérix chez Rahazade">Personnages d'Astérix chez Rahazade</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-16" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_les_Belges" title="Catégorie:Personnages d'Astérix chez les Belges">Personnages d'Astérix chez les Belges</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-17" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_les_Pictes" title="Catégorie:Personnages d'Astérix chez les Pictes">Personnages d'Astérix chez les Pictes</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-18" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_les_Bretons_(film)" title="Catégorie:Personnages d'Astérix chez les Bretons (film)">Personnages d'Astérix chez les Bretons (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-19" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_le_Chaudron" title="Catégorie:Personnages d'Astérix et le Chaudron">Personnages d'Astérix et le Chaudron</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-20" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_la_Transitalique" title="Catégorie:Personnages d'Astérix et la Transitalique">Personnages d'Astérix et la Transitalique</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-21" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_Cl%C3%A9opatre_(film)" title="Catégorie:Personnages d'Astérix et Cléopatre (film)">Personnages d'Astérix et Cléopatre (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-22" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_la_Surprise_de_C%C3%A9sar_(film)" title="Catégorie:Personnages d'Astérix et la Surprise de César (film)">Personnages d'Astérix et la Surprise de César (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-23" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_le_Gaulois" title="Catégorie:Personnages d'Astérix le Gaulois">Personnages d'Astérix le Gaulois</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-24" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_le_Gaulois_(film)" title="Catégorie:Personnages d'Astérix le Gaulois (film)">Personnages d'Astérix le Gaulois (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-25" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_La_Zizanie" title="Catégorie:Personnages de La Zizanie">Personnages de La Zizanie</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-26" href="/fr/wiki/Cat%C3%A9gorie:Personnages_des_Lauriers_de_C%C3%A9sar" title="Catégorie:Personnages des Lauriers de César">Personnages des Lauriers de César</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-27" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_La_Grande_Travers%C3%A9e" title="Catégorie:Personnages de La Grande Traversée">Personnages de La Grande Traversée</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-28" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_films_en_prises_de_vues_r%C3%A9elles" title="Catégorie:Personnages de films en prises de vues réelles">Personnages de films en prises de vues réelles</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-29" href="/fr/wiki/Cat%C3%A9gorie:Personnages_des_Douze_Travaux_d%27Ast%C3%A9rix_(film)" title="Catégorie:Personnages des Douze Travaux d'Astérix (film)">Personnages des Douze Travaux d'Astérix (film)</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-30" href="/fr/wiki/Cat%C3%A9gorie:Personnages_des_aventures_d%27Ast%C3%A9rix_le_Gaulois" title="Catégorie:Personnages des aventures d'Astérix le Gaulois">Personnages des aventures d'Astérix le Gaulois</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-31" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_l%27Odyss%C3%A9e_d%27Ast%C3%A9rix" title="Catégorie:Personnages de l'Odyssée d'Astérix">Personnages de l'Odyssée d'Astérix</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-32" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Menhir_d%27or" title="Catégorie:Personnages du Menhir d'or">Personnages du Menhir d'or</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-33" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_les_Goths" title="Catégorie:Personnages d'Astérix et les Goths">Personnages d'Astérix et les Goths</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-34" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_les_Normands" title="Catégorie:Personnages d'Astérix et les Normands">Personnages d'Astérix et les Normands</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-35" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_les_Vikings_(film)" title="Catégorie:Personnages d'Astérix et les Vikings (film)">Personnages d'Astérix et les Vikings (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-36" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_les_Indiens_(film)" title="Catégorie:Personnages d'Astérix et les Indiens (film)">Personnages d'Astérix et les Indiens (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-37" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_le_Coup_du_Menhir_(film)" title="Catégorie:Personnages d'Astérix et le Coup du Menhir (film)">Personnages d'Astérix et le Coup du Menhir (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-38" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_Gladiateur" title="Catégorie:Personnages d'Astérix Gladiateur">Personnages d'Astérix Gladiateur</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-39" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Domaine_des_Dieux" title="Catégorie:Personnages du Domaine des Dieux">Personnages du Domaine des Dieux</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-40" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Devin" title="Catégorie:Personnages du Devin">Personnages du Devin</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-41" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Grand_Foss%C3%A9" title="Catégorie:Personnages du Grand Fossé">Personnages du Grand Fossé</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-42" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Fils_d%27Ast%C3%A9rix" title="Catégorie:Personnages du Fils d'Astérix">Personnages du Fils d'Astérix</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-43" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Ciel_lui_Tombe_sur_la_T%C3%AAte" title="Catégorie:Personnages du Ciel lui Tombe sur la Tête">Personnages du Ciel lui Tombe sur la Tête</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-44" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Domaine_des_Dieux_(film)" title="Catégorie:Personnages du Domaine des Dieux (film)">Personnages du Domaine des Dieux (film)</a> </li>
# <li>
# <a data-tracking-label="categories-top-more-45" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Tour_de_Gaule_d%27Ast%C3%A9rix" title="Catégorie:Personnages du Tour de Gaule d'Astérix">Personnages du Tour de Gaule d'Astérix</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-46" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Combat_des_Chefs" title="Catégorie:Personnages du Combat des Chefs">Personnages du Combat des Chefs</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-47" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Cadeau_de_C%C3%A9sar" title="Catégorie:Personnages du Cadeau de César">Personnages du Cadeau de César</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-48" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_Cl%C3%A9opatre" title="Catégorie:Personnages d'Astérix et Cléopatre">Personnages d'Astérix et Cléopatre</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-49" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_l%C3%A9gionnaire" title="Catégorie:Personnages d'Astérix légionnaire">Personnages d'Astérix légionnaire</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-50" href="/fr/wiki/Cat%C3%A9gorie:Personnages_du_Bouclier_Arverne" title="Catégorie:Personnages du Bouclier Arverne">Personnages du Bouclier Arverne</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-51" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_aux_Jeux_Olympiques" title="Catégorie:Personnages d'Astérix aux Jeux Olympiques">Personnages d'Astérix aux Jeux Olympiques</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-52" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_aux_Jeux_Olympiques_(film)" title="Catégorie:Personnages d'Astérix aux Jeux Olympiques (film)">Personnages d'Astérix aux Jeux Olympiques (film)</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-53" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_chez_les_Helv%C3%A8tes" title="Catégorie:Personnages d'Astérix chez les Helvètes">Personnages d'Astérix chez les Helvètes</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-54" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ob%C3%A9lix_et_Compagnie" title="Catégorie:Personnages d'Obélix et Compagnie">Personnages d'Obélix et Compagnie</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-55" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_La_Rose_et_le_Glaive" title="Catégorie:Personnages de La Rose et le Glaive">Personnages de La Rose et le Glaive</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-56" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_la_Gal%C3%A8re_d%27Ob%C3%A9lix" title="Catégorie:Personnages de la Galère d'Obélix">Personnages de la Galère d'Obélix</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-57" href="/fr/wiki/Cat%C3%A9gorie:Personnages_de_La_Fille_de_Vercing%C3%A9torix" title="Catégorie:Personnages de La Fille de Vercingétorix">Personnages de La Fille de Vercingétorix</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-58" href="/fr/wiki/Cat%C3%A9gorie:Personnages_d%27Ast%C3%A9rix_et_Ob%C3%A9lix_:_Au_service_de_Sa_Majest%C3%A9" title="Catégorie:Personnages d'Astérix et Obélix : Au service de Sa Majesté">Personnages d'Astérix et Obélix : Au service de Sa Majesté</a> </li>
# <li>
# <a class="newcategory" data-tracking-label="categories-top-more-59" href="/fr/wiki/Cat%C3%A9gorie:Ast%C3%A9rix_et_Ob%C3%A9lix_:_Au_service_de_Sa_Majest%C3%A9" title="Catégorie:Astérix et Obélix : Au service de Sa Majesté">Astérix et Obélix : Au service de Sa Majesté</a> </li>
# </ul>
# </div>
# </div>
# </div>]
# aaa
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14048/4274149654.py in <module>
#       7         result = requests.get(v)
#       8         c = result.content
# ----> 9         soup = BeautifulSoup(c, "html.parser")  # parse HTML page
#      10         links = soup.find_all("div", class_='page-header__categories')
#      11         #links2 = soup.find_all("a", class_='page-header__categories')https://lotr.fandom.com/wiki/Category:Characters_in_The_History_of_Middle-earth
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     360             self.reset()
#     361             try:
# --> 362                 self._feed()
#     363                 success = True
#     364                 break
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\__init__.py in _feed(self)
#     446         self.builder.reset()
#     447
# --> 448         self.builder.feed(self.markup)
#     449         # Close out any unfinished strings and close all the open tags.
#     450         self.endData()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\builder\_htmlparser.py in feed(self, markup)
#     390         parser.soup = self.soup
#     391         try:
# --> 392             parser.feed(markup)
#     393             parser.close()
#     394         except HTMLParseError as e:
#
# ~\AppData\Local\Programs\Python\Python39\lib\html\parser.py in feed(self, data)
#     108         """
#     109         self.rawdata = self.rawdata + data
# --> 110         self.goahead(0)
#     111
#     112     def close(self):
#
# ~\AppData\Local\Programs\Python\Python39\lib\html\parser.py in goahead(self, end)
#     168             if startswith('<', i):
#     169                 if starttagopen.match(rawdata, i): # < + letter
# --> 170                     k = self.parse_starttag(i)
#     171                 elif startswith("</", i):
#     172                     k = self.parse_endtag(i)
#
# ~\AppData\Local\Programs\Python\Python39\lib\html\parser.py in parse_starttag(self, i)
#     342             self.handle_startendtag(tag, attrs)
#     343         else:
# --> 344             self.handle_starttag(tag, attrs)
#     345             if tag in self.CDATA_CONTENT_ELEMENTS:
#     346                 self.set_cdata_mode(tag)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\builder\_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#     149         #print("START", name)
#     150         sourceline, sourcepos = self.getpos()
# --> 151         tag = self.soup.handle_starttag(
#     152             name, None, None, attr_dict, sourceline=sourceline,
#     153             sourcepos=sourcepos
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos)
#     707         """
#     708         # print("Start tag %s: %s" % (name, attrs))
# --> 709         self.endData()
#     710
#     711         if (self.parse_only and len(self.tagStack) <= 1
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\__init__.py in endData(self, containerClass)
#     585             containerClass = self.string_container(containerClass)
#     586             o = containerClass(current_data)
# --> 587             self.object_was_parsed(o)
#     588
#     589     def object_was_parsed(self, o, parent=None, most_recent_element=None):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\__init__.py in object_was_parsed(self, o, parent, most_recent_element)
#     604                 previous_element = o.previous_element
#     605
# --> 606         fix = parent.next_element is not None
#     607
#     608         o.setup(parent, previous_element, next_element, previous_sibling, next_sibling)
#
# KeyboardInterrupt:

# %%
print(characters_dict.items())
# Out:
# dict_items([('Asterix_(Character)', 'https://asterix.fandom.com/wiki/Asterix_(Character)'), ('Impedimenta', 'https://asterix.fandom.com/wiki/Impedimenta'), ('Bacteria', 'https://asterix.fandom.com/wiki/Bacteria'), ('The_Pirates', 'https://asterix.fandom.com/wiki/The_Pirates'), ('Odius_Asparagus', 'https://asterix.fandom.com/wiki/Odius_Asparagus'), ('Overanxius', 'https://asterix.fandom.com/wiki/Overanxius'), ('Gracchus_Armisurplus', 'https://asterix.fandom.com/wiki/Gracchus_Armisurplus'), ('Crismus_Bonus', 'https://asterix.fandom.com/wiki/Crismus_Bonus'), ('Surplus_Dairiprodus', 'https://asterix.fandom.com/wiki/Surplus_Dairiprodus'), ('Metallurgix', 'https://asterix.fandom.com/wiki/Metallurgix'), ('Cantankerus', 'https://asterix.fandom.com/wiki/Cantankerus'), ('Redbeard', 'https://asterix.fandom.com/wiki/Redbeard'), ('Metric', 'https://asterix.fandom.com/wiki/Metric'), ('Cleopatra', 'https://asterix.fandom.com/wiki/Cleopatra'), ('Alcoholix', 'https://asterix.fandom.com/wiki/Alcoholix'), ('Navishtrix', 'https://asterix.fandom.com/wiki/Navishtrix'), ('C%C3%A9sar_Drinklikafix', 'https://asterix.fandom.com/wiki/C%C3%A9sar_Drinklikafix'), ('Clovogarlix', 'https://asterix.fandom.com/wiki/Clovogarlix'), ('Edifis', 'https://asterix.fandom.com/wiki/Edifis'), ('Caligula_Minus', 'https://asterix.fandom.com/wiki/Caligula_Minus'), ('Caius_Fatuous', 'https://asterix.fandom.com/wiki/Caius_Fatuous'), ('Ekonomikrisis', 'https://asterix.fandom.com/wiki/Ekonomikrisis'), ('Claudius_M%C3%A9trobus', 'https://asterix.fandom.com/wiki/Claudius_M%C3%A9trobus'), ('Pirate_Lookout', 'https://asterix.fandom.com/wiki/Pirate_Lookout'), ('Erix', 'https://asterix.fandom.com/wiki/Erix'), ('Choleric', 'https://asterix.fandom.com/wiki/Choleric'), ('Atmospheric,_Prehsitoric,_Tartaric,_Esoteric', 'https://asterix.fandom.com/wiki/Atmospheric,_Prehsitoric,_Tartaric,_Esoteric'), ('Anticlimax', 'https://asterix.fandom.com/wiki/Anticlimax'), ('Tullius_Octopus', 'https://asterix.fandom.com/wiki/Tullius_Octopus'), ('Caius_Flebitus,_Gracchus_Sextilius_and_Claudius_Quintilius', 'https://asterix.fandom.com/wiki/Caius_Flebitus,_Gracchus_Sextilius_and_Claudius_Quintilius'), ('Julius_Pompus', 'https://asterix.fandom.com/wiki/Julius_Pompus'), ('_Amonbofis', 'https://asterix.fandom.com/wiki/Artifis_/_Amonbofis'), ('Krukhut', 'https://asterix.fandom.com/wiki/Krukhut'), ('Gastroenteritus_and_Arteriosclerosus', 'https://asterix.fandom.com/wiki/Gastroenteritus_and_Arteriosclerosus'), ('Instantmix', 'https://asterix.fandom.com/wiki/Instantmix'), ('Prefix', 'https://asterix.fandom.com/wiki/Prefix'), ('Tenansix', 'https://asterix.fandom.com/wiki/Tenansix'), ('Porpus', 'https://asterix.fandom.com/wiki/Porpus'), ('Felix_Platypus', 'https://asterix.fandom.com/wiki/Felix_Platypus'), ('Gluteus_Maximus', 'https://asterix.fandom.com/wiki/Gluteus_Maximus'), ('Berlix', 'https://asterix.fandom.com/wiki/Berlix'), ('Bicarbonatofsoda', 'https://asterix.fandom.com/wiki/Bicarbonatofsoda'), ('Botanix', 'https://asterix.fandom.com/wiki/Botanix'), ('Cassius_Ceramix', 'https://asterix.fandom.com/wiki/Cassius_Ceramix'), ('Chanticleerix', 'https://asterix.fandom.com/wiki/Chanticleerix'), ('Codfix', 'https://asterix.fandom.com/wiki/Codfix'), ('Hydrophobia', 'https://asterix.fandom.com/wiki/Hydrophobia'), ('Jellibabix', 'https://asterix.fandom.com/wiki/Jellibabix'), ('Justforkix', 'https://asterix.fandom.com/wiki/Justforkix'), ('Picanmix', 'https://asterix.fandom.com/wiki/Picanmix'), ('Prawnsinaspix', 'https://asterix.fandom.com/wiki/Prawnsinaspix'), ('Psychoanalytix', 'https://asterix.fandom.com/wiki/Psychoanalytix'), ('Seniorservix', 'https://asterix.fandom.com/wiki/Seniorservix'), ('Tunafix', 'https://asterix.fandom.com/wiki/Tunafix'), ('Unpatriotix', 'https://asterix.fandom.com/wiki/Unpatriotix'), ('Uptotrix', 'https://asterix.fandom.com/wiki/Uptotrix'), ('Valueaddedtax', 'https://asterix.fandom.com/wiki/Valueaddedtax'), ('Adipus', 'https://asterix.fandom.com/wiki/Adipus'), ('Appianglorious', 'https://ast ...

# %%
import itertools
inverted_dict = {v.encode('utf-8'): k for k, v in characters_dict.items()}
dict(itertools.islice(inverted_dict.items(), 0, 4))
# Out:
# {b'https://asterix.fandom.com/wiki/Asterix_(Character)': 'Asterix_(Character)',
#  b'https://asterix.fandom.com/wiki/Impedimenta': 'Impedimenta',
#  b'https://asterix.fandom.com/wiki/Bacteria': 'Bacteria',
#  b'https://asterix.fandom.com/wiki/The_Pirates': 'The_Pirates'}

# %%
import collections
from lxml import html
import pandas as pd
character_count=collections.Counter()
character_text=dict()
character_network = collections.Counter()

characters_details=[]
for character_url, character_name in inverted_dict.items():
    character_html = requests.get(character_url)
    page = html.fromstring(character_html.text)
    soup = BeautifulSoup(character_html.content, "html.parser")
    if (character_name == "Asterix_(Character)"):
        character_name = "Asterix"    

    character_name = unquote(character_name)

    character = {'name':character_name, 'url':character_url, 'html_content':character_html.text }    

    c = []
    s = soup.find('div',{'id':'mw-content-text'})
    if (s is None):
        continue
    for link in s.find_all('a'):
        #print(base_url+str(link.get('href').encode('utf-8')))
        if (link.get('href')) is None:
            continue
        l = (base_url+str(link.get('href').encode('utf-8')))
        d = (base_url+str(link.get('href')))
        if link.get('href') == "/wiki/Asterix" and d.encode('UTF-8') and "https://asterix.fandom.com/wiki/Asterix" not in c:
            print("on ajoute")
            c.append("https://asterix.fandom.com/wiki/Asterix_(Character)")
        if link.get('href') and d.encode('UTF-8') in inverted_dict.keys() and d not in c:
            c.append(d)
    #c = [inverted_dict[base_url+link.get('href').encode('utf-8')] for link in soup.find('div',{'id':'mw-content-text'}).find_all('a') if link.get('href') and (base_url+str(link.get('href').encode('utf-8'))) in inverted_dict]
    lotr_dict={'character_name':character_name,'character_url': character_url.decode("utf-8"),'links':c}
    #lotr_name = soup.find("h2", class_="pi-item pi-item-spacing pi-title")
    characters_details.append(lotr_dict)
print(len(characters_details))
# Out:
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# on ajoute
# 147

# %%
import json
with open(saved_file, 'w') as outfile:
    json.dump(characters_details, outfile)
